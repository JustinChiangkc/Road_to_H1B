# %%
# !pip install plotly==4.6.0
# Out:
# ...
#      |████████████████████████████████| 7.1 MB 2.6 MB/s eta 0:00:01
# ...
#   Created wheel for retrying: filename=retrying-1.3.3-py3-none-any.whl size=11429 sha256=b0e35b21c47810bd4f5e1fde54102b32e91b7b05a0a83e3e93cff4627263d499
#   Stored in directory: /Users/justinchiang/Library/Caches/pip/wheels/f9/8d/8d/f6af3f7f9eea3553bc2fe6d53e4b287dad18b06a861ac56ddf
# Successfully built retrying
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline

# %%
# df09 = pd.read_csv("h1b_datahubexport-2009.csv")
# df10 = pd.read_csv("h1b_datahubexport-2010.csv")
# df11 = pd.read_csv("h1b_datahubexport-2011.csv")
# df12 = pd.read_csv("h1b_datahubexport-2012.csv")
# df13 = pd.read_csv("h1b_datahubexport-2013.csv")
# df14 = pd.read_csv("h1b_datahubexport-2014.csv")
# df15 = pd.read_csv("h1b_datahubexport-2015.csv")
# df16 = pd.read_csv("h1b_datahubexport-2016.csv")
# df17 = pd.read_csv("h1b_datahubexport-2017.csv")
# df18 = pd.read_csv("h1b_datahubexport-2018.csv")
# df19 = pd.read_csv("h1b_datahubexport-2019.csv")
# Out:
# /Users/justinchiang/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3057: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# df = pd.concat([df09,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19])

# %%
# df.to_csv("h1b_datahubexport-09-19.csv")

# %%
df = pd.read_csv("data/h1b_datahubexport-09-19.csv",low_memory=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 622684 entries, 0 to 622683
# Data columns (total 12 columns):
# Unnamed: 0              622684 non-null int64
# Fiscal Year             622684 non-null int64
# Employer                622516 non-null object
# Initial Approvals       622684 non-null object
# Initial Denials         622684 non-null object
# Continuing Approvals    622684 non-null object
# Continuing Denials      622684 non-null object
# NAICS                   622684 non-null int64
# Tax ID                  620751 non-null float64
# State                   622518 non-null object
# City                    622660 non-null object
# ZIP                     622533 non-null float64
# dtypes: float64(2), int64(3), object(7)
# memory usage: 57.0+ MB

# %%
df.nunique()
# Out:
# Unnamed: 0               68919
# Fiscal Year                 11
# Employer                285772
# Initial Approvals          492
# Initial Denials            154
# Continuing Approvals       670
# Continuing Denials         150
# NAICS                       25
# Tax ID                   10000
# State                       59
# City                      8824
# ZIP                      16686
# dtype: int64

# %%
df2 = df.drop(["Tax ID","City", "ZIP"], axis=1)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 622684 entries, 0 to 622683
# Data columns (total 9 columns):
# Unnamed: 0              622684 non-null int64
# Fiscal Year             622684 non-null int64
# Employer                622516 non-null object
# Initial Approvals       622684 non-null object
# Initial Denials         622684 non-null object
# Continuing Approvals    622684 non-null object
# Continuing Denials      622684 non-null object
# NAICS                   622684 non-null int64
# State                   622518 non-null object
# dtypes: int64(3), object(6)
# memory usage: 42.8+ MB

# %%
df3 = df2.dropna()

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 622350 entries, 1 to 622683
# Data columns (total 9 columns):
# Unnamed: 0              622350 non-null int64
# Fiscal Year             622350 non-null int64
# Employer                622350 non-null object
# Initial Approvals       622350 non-null object
# Initial Denials         622350 non-null object
# Continuing Approvals    622350 non-null object
# Continuing Denials      622350 non-null object
# NAICS                   622350 non-null int64
# State                   622350 non-null object
# dtypes: int64(3), object(6)
# memory usage: 47.5+ MB

# %%
df3.columns
# Out:
# Index(['Unnamed: 0', 'Fiscal Year', 'Employer', 'Initial Approvals',
#        'Initial Denials', 'Continuing Approvals', 'Continuing Denials',
#        'NAICS', 'State'],
#       dtype='object')

# %%
df2018 = df3[df3["Fiscal Year"] == 2018]

# %%
df2018.Employer.nunique()
# Out:
# 48972

# %%
df2018.Employer.shape
# Out:
# (55657,)

# %%
import numpy as np

# %%
df3[['Initial Approvals','Initial Denials', 'Continuing Approvals', 'Continuing Denials']] = (df3[['Initial Approvals','Initial Denials', 'Continuing Approvals', 'Continuing Denials']]
 .apply(lambda x: x.str.replace(',','')).astype(np.int64)
)
# Out:
# /Users/justinchiang/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3391: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 622350 entries, 1 to 622683
# Data columns (total 9 columns):
# Unnamed: 0              622350 non-null int64
# Fiscal Year             622350 non-null int64
# Employer                622350 non-null object
# Initial Approvals       622350 non-null int64
# Initial Denials         622350 non-null int64
# Continuing Approvals    622350 non-null int64
# Continuing Denials      622350 non-null int64
# NAICS                   622350 non-null int64
# State                   622350 non-null object
# dtypes: int64(7), object(2)
# memory usage: 67.5+ MB

# %%
df3.head()
# Out:
#   Programming language  Job counts
# 0                    C        2517
# 1                  C++        2891
# 2                 JAVA        1339
# 3                Scala        1325
# 4               Python        3966

# %%
df3["

# %%
df3["Initial Approvals"].value_counts().plot(kind='bar', figsize=(10, 6))

# %%
df4
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Fiscal Year, Employer, Initial Approvals, Initial Denials, Continuing Approvals, Continuing Denials, NAICS, State]
# Index: []

# %%
#toint
df2.head()
# Out:
#      Unnamed: 0  Fiscal Year                        Employer  \
# 496         496         2009          DECISION RESOURCES INC
# 497         497         2009                      MIXXIL LLC
# 498         498         2009  POLARIS SOFTWARE LAD INDIA LTD
# 499         499         2009                    ESYSTEMS INC
# 500         500         2009   BANGOR HYDRO-ELECTRIC COMPANY
#
#     Initial Approvals Initial Denials Continuing Approvals Continuing Denials  \
# 496                 0               0                    1                  0
# 497                 0               1                    0                  0
# 498                 2               0                    0                  0
# 499                 1               0                    0                  0
# 500                 1               0                    0                  0
#
#      NAICS  Tax ID State       City     ZIP
# 496     54  9274.0    MA    WALTHAM  2453.0
# ...

# %%
df2.describe()
# Out:
#           Unnamed: 0    Fiscal Year          NAICS         Tax ID  \
# count  620416.000000  620416.000000  620416.000000  620416.000000
# mean    28652.310387    2013.844577      54.111522    4941.870066
# std     16755.748968       3.235923      15.130890    2894.900364
# min        74.000000    2009.000000      11.000000       0.000000
# 25%     14283.000000    2011.000000      51.000000    2412.000000
# 50%     28390.000000    2014.000000      54.000000    4926.000000
# 75%     42498.250000    2017.000000      61.000000    7445.000000
# max     68918.000000    2019.000000      99.000000    9999.000000
#
#                  ZIP
# count  620416.000000
# mean    48194.545829
# std     33620.600100
# min       605.000000
# 25%     13501.000000
# 50%     44143.000000
# 75%     80301.000000
# max     99929.000000

# %%
df2["Tax ID"].value_counts()
# Out:
# 3200.0    430
# 2033.0    284
# 235.0     269
# 7987.0    246
# 6300.0    240
# 7393.0    237
# 6492.0    237
# 650.0     235
# 6908.0    219
# 434.0     215
# 2229.0    214
# 9340.0    213
# 3536.0    212
# 9806.0    206
# 1347.0    204
# 2743.0    190
# 1980.0    187
# 1430.0    181
# 2284.0    180
# 8361.0    179
# 4155.0    178
# 7820.0    173
# 4442.0    172
# 3240.0    170
# 5641.0    169
# 5001.0    168
# 8140.0    167
# 1099.0    166
# 3470.0    165
# 1131.0    162
#          ...
# 6452.0     18
# 8716.0     18
# 9606.0     18
# 1896.0     18
# 2183.0     18
# 7744.0     18
# 5346.0     18
# 5504.0     18
# 4457.0     18
# 1015.0     18
# 1213.0     18
# 2571.0     17
# 8049.0     17
# 4761.0     17
# 7169.0     17
# 4319.0     17
# 249.0      17
# 3061.0     16
# 5085.0     16
# 8152.0     16
# 8299.0     16
# 5184.0     16
# 5713.0     16
# 4880.0     15
# 6728.0     14
# 6322.0     14
# 5699.0     12
# 5241.0     12
# 8179.0     12
# 1458.0     11
# ...

# %%
df2[df2["State"] == "NEW YORK"]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Fiscal Year, Employer, Initial Approvals, Initial Denials, Continuing Approvals, Continuing Denials, NAICS, State]
# Index: []

# %%
df2[df2["Tax ID"] ==1458.0   ]
# Out:
#         Unnamed: 0  Fiscal Year                            Employer  \
# 6083          6083         2009                    SHAMA RASOOL M D
# 52945        52945         2009                         NEOHIRE COM
# 92999        24080         2010  19 ST ENTERPRISE INC D/B/A CHARLES
# 155088       30740         2011         GEMSTONE COMMUNICATIONS INC
# 162987       38639         2011  AVILA CAPITAL MGT LLC D/B/A ORINOC
# 254430       10986         2013  WORLD COUNCIL FOR ECONOMIC DEVELOP
# 325404       25881         2014         GEMSTONE COMMUNICATIONS INC
# 384231       28113         2015         EATON HALL ARCHITECTURE INC
# 477290       19499         2017                        MOTIVATE INC
# 528798       21221         2018                        MOTIVATE INC
# 558372       50795         2018       COLORADO SYMPHONY ASSOCIATION
#
#        Initial Approvals Initial Denials Continuing Approvals  \
# 6083                   0               0                    1
# ...

# %%
df2[df2["Employer"].str.contains('goog', case=False, regex=True) ]
#test if tax id could present employer, the answer is no
# Out:
#         Unnamed: 0  Fiscal Year                          Employer  \
# 19982        19982         2009                        GOOGLE INC
# 45008        45008         2009  GOOGLEPLEX D/B/AALTERNATIVEPATHS
# 58614        58614         2009                        GOOGLE INC
# 58615        58615         2009                        GOOGLE INC
# 61819        61819         2009                    GOOGOZ COM INC
# 102857       33938         2010         GOOGLE (ITA SOFTWARE INC)
# 116034       47115         2010                        GOOGLE INC
# 116035       47116         2010                        GOOGLE INC
# 116424       47505         2010                        GOOGLE INC
# 120725       51806         2010                    GOOGOZ COM INC
# 163726       39378         2011         GOOGLE (ITA SOFTWARE INC)
# 178220       53872         2011                        GOOGLE INC
# 178221       53873         2011                        GOOGLE INC
# ...

# %%
states = "[AZ], [SC], [LA], [MN], [NJ], [DC], [OR], [VA], [RI], [KY], [WY], [NH], [MI], [NV], [WI], [ID], [CA], [CT], [NE], [MT], [NC], [VT], [MD], [DE], [MO], [VI], [IL], [ME], [GU], [WA], [ND], [MS], [AL], [IN], [AE], [?], [OH], [TN], [IA], [NM], [PA], [SD], [NY], [FM], [TX], [WV], [NEW YORK], [GA], [MA], [KS], [FL], [CO], [AK], [AR], [OK], [PR], [AP], [MP], [UT], [HI]"
stateslist = states.split(",")

# %%
stateslist2 = [s.strip(" ").strip("[").strip("]") for s in stateslist]

# %%
stateslist2
# Out:
# ['AZ',
#  'SC',
#  'LA',
#  'MN',
#  'NJ',
#  'DC',
#  'OR',
#  'VA',
#  'RI',
#  'KY',
#  'WY',
#  'NH',
#  'MI',
#  'NV',
#  'WI',
#  'ID',
#  'CA',
#  'CT',
#  'NE',
#  'MT',
#  'NC',
#  'VT',
#  'MD',
#  'DE',
#  'MO',
#  'VI',
#  'IL',
#  'ME',
#  'GU',
#  'WA',
#  'ND',
#  'MS',
#  'AL',
#  'IN',
#  'AE',
#  '?',
#  'OH',
#  'TN',
#  'IA',
#  'NM',
#  'PA',
#  'SD',
#  'NY',
#  'FM',
#  'TX',
#  'WV',
#  'NEW YORK',
#  'GA',
#  'MA',
#  'KS',
#  'FL',
#  'CO',
#  'AK',
#  'AR',
#  'OK',
#  'PR',
#  'AP',
#  'MP',
#  'UT',
#  'HI']

# %%
real = "AK,AL,AZ,AR,CA,CO,CT,DE,DC,FL,GA,HI,ID,IL,IN,IA,KS,KY,LA,ME,MD,MA,MI,MN,MS,MO,MT,NB,NV,NH,NJ,NM,NY,NC,ND,OH,OK,OR,PA,RI,SC,SD,TN,TX,UT,VT,VA,WA,WV,WI,WY"

# %%
reallist = real.split(",")

# %%
reallist
# Out:
# ['AK',
#  'AL',
#  'AZ',
#  'AR',
#  'CA',
#  'CO',
#  'CT',
#  'DE',
#  'DC',
#  'FL',
#  'GA',
#  'HI',
#  'ID',
#  'IL',
#  'IN',
#  'IA',
#  'KS',
#  'KY',
#  'LA',
#  'ME',
#  'MD',
#  'MA',
#  'MI',
#  'MN',
#  'MS',
#  'MO',
#  'MT',
#  'NB',
#  'NV',
#  'NH',
#  'NJ',
#  'NM',
#  'NY',
#  'NC',
#  'ND',
#  'OH',
#  'OK',
#  'OR',
#  'PA',
#  'RI',
#  'SC',
#  'SD',
#  'TN',
#  'TX',
#  'UT',
#  'VT',
#  'VA',
#  'WA',
#  'WV',
#  'WI',
#  'WY']

# %%
c = 0 
for a in stateslist2:
    if a not in reallist:
        print(a)
    else:
        c+=1
# Out:
# NE
# VI
# GU
# AE
# ?
# FM
# NEW YORK
# PR
# AP
# MP

# %%
c
# Out:
# 50

# %%
len(stateslist2)
# Out:
# 60

# %%
reallist
# Out:
# 'AK,AL,AZ,AR,CA,CO,CT,DE,DC,FL,GA,HI,ID,IL,IN,IA,KS,KY,LA,ME,MD,MA,MI,MN,MS,MO,MT,NB,NV,NH,NJ,NM,NY,NC,ND,OH,OK,OR,PA,PR,RI,SC,SD,TN,TX,UT,VT,VA,VI,WA,WV,WI,WY'

# %%
import seaborn as sns
mlskill = ["sklean","pytorch","tensorflow","mllib","keras"]

df = pd.DataFrame(salary,
                  columns= mlskill)

# ax = sns.boxplot(x="day", y="total_bill", data=tips)

# %%
ax = sns.boxplot(data=df)
ax.set(xlabel='ML Package',ylabel='Annual Salary')
ax.set_title('ML package_Salary Boxplot')
plt.figure(figsize=(20, 10))

# %%
ss1 = np.random.randint(low=80000, high=150000, size=5)
ss2 = np.random.randint(low=80000, high=150000, size=5)
ss3 = np.random.randint(low=80000, high=150000, size=5)
ss4 = np.random.randint(low=80000, high=150000, size=5)
ss5 = np.random.randint(low=80000, high=150000, size=5)
salary = [ss1,ss2,ss3,ss4,ss5]

# %%
ss1 = np.random.randint(low=1000, high=5000, size=5)
ss2 = np.random.randint(low=1000, high=5000, size=5)
ss3 = np.random.randint(low=1000, high=5000, size=5)
ss4 = np.random.randint(low=1000, high=5000, size=5)
ss5 = np.random.randint(low=1000, high=5000, size=5)

jn = [ss1,ss2,ss3,ss4,ss5]
PL = ["C","C++","JAVA","Scala","Python"]
df2 = pd.DataFrame(salary,
                  columns= PL)
ax = sns.boxplot(data=df2)
ax.set(xlabel='Programming language',ylabel='Annual Salary')
ax.set_title('Programming language_Salary Boxplot')
plt.figure(figsize=(20, 10))

# %%
df3 = pd.DataFrame(ss1, index =PL)

# %%
import numpy as np
import matplotlib.pyplot as plt
 
# Fake dataset
height = ss2
bars = mlskill
y_pos = np.arange(len(bars))
 
# Create bars and choose color
plt.bar(y_pos, height, color = (0.5,0.1,0.5,0.6))
 
# Add title and axis names
plt.title('ML package job counts')
plt.xlabel('ML package')
plt.ylabel('Job counts')
 
# Limits for the Y axis
# plt.ylim(0,60)
 
# Create names
plt.xticks(y_pos, bars)
 
# Show graphic
plt.show()

# %%
plt.style.use('ggplot')
df3 = pd.DataFrame({'Programming language':PL, 'Job counts':ss1})
df3.plot.bar(x='Programming language', y='Job counts')
df3.title = "Programming language job counts"

# %%
ax = sns.barplot(data=df3)
# ax.set(xlabel='Programming language',ylabel='Job counts')
# ax.set_title('Programming language_Job counts Boxplot')
# plt.figure(figsize=(20, 10))
