# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline

# %%
df = pd.read_csv("salary/h1b_salary_clean.txt",header = None,sep = "," ,low_memory=False)

# %%
df[3].value_counts()
# Out:
# CERTIFIED    245465
# WITHDRAWN      9778
# DENIED         2661
# Name: 3, dtype: int64

# %%
df2 = pd.read_csv("salary_skill_joined/part-00000",header = None,sep = "," ,low_memory=False)

# %%
df2
# Out:
#                 0                   1         2          3   4     5    6  \
# 0      ((crescent  software engineer)  ((100000  CERTIFIED  CA  2015   3)
# 1    ((foundation  software engineer)   ((70000  CERTIFIED  OH  2017   3)
# 2           ((ubs  software engineer)   ((70500  CERTIFIED  NY  2017   3)
# 3           ((ubs  software engineer)   ((69500  WITHDRAWN  NJ  2012   3)
# 4           ((ubs  software engineer)   ((69500  WITHDRAWN  NJ  2012   3)
# 5           ((ubs  software engineer)   ((69500  WITHDRAWN  NJ  2012   3)
# 6           ((ubs  software engineer)   ((70970  WITHDRAWN  NJ  2012  12)
# 7           ((ubs  software engineer)   ((70970  WITHDRAWN  NJ  2013   1)
# 8           ((ubs  software engineer)  ((110000  CERTIFIED  NJ  2014  12)
# 9           ((ubs  software engineer)   ((75000  WITHDRAWN  NJ  2014   4)
# 10          ((ubs  software engineer)   ((81000  WITHDRAWN  NJ  2014   5)
# 11          ((ubs  software engineer)   ((81000  WITHDRAWN  NJ  2015   3)
# ...
